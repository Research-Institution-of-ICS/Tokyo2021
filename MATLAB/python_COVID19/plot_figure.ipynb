# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure(2)
ax = fig.add_subplot(111)
ax.set(xlim=[0.5, 4.5], ylim=[-2, 8], title='An Example Axes',
       ylabel='Y-Axis', xlabel='X-Axis')
plt.show()

# %%
fig = plt.figure()
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
ax3  = fig.add_subplot(223)
ax4 = fig.add_subplot(224)
import numpy as np 
x = np.linspace(0, np.pi)
y_sin = np.sin(x)
y_cos = np.cos(x)

ax1.plot(x, y_sin)
ax2.plot(x, y_sin, 'go--', linewidth=2, markersize=12)
ax3.plot(x, y_cos, color='red', marker='+', linestyle='dashed')
plt.show()

# %%
import numpy as np 
x = np.linspace(0, np.pi)
y_sin = np.sin(x)
y_cos = np.cos(x)

ax1.plot(x, y_sin)
ax2.plot(x, y_sin, 'go--', linewidth=2, markersize=12)
ax3.plot(x, y_cos, color='red', marker='+', linestyle='dashed')
plt.show()

# %%
x = np.linspace(0, 10, 200)
data_obj = {'x': x,
            'y1': 2 * x + 1,
            'y2': 3 * x + 1.2,
            'mean': 0.5 * x * np.cos(2*x) + 2.5 * x + 1.1}

fig, ax = plt.subplots()

#填充两条线之间的颜色
ax.fill_between('x', 'y1', 'y2', color='yellow', data=data_obj)

# Plot the "centerline" with `plot`
ax.plot('x', 'mean', color='black', data=data_obj)
ax.legend()
plt.show()

# %%
x = np.arange(10)
y = np.random.randn(10)
plt.scatter(x, y, color='red', marker='+')
plt.show()

# %%
import matplotlib.pyplot as plt
from scipy.io import loadmat 
import numpy as np

# %%
data = loadmat('./strategy_result/NO_str.mat')
no_str_I = np.sum(data['I_result'],1)
no_str_R = np.sum(data['R_result'],1)
no_str = no_str_I + no_str_R
data = loadmat('./strategy_result/str_1.mat')
str_1 = np.sum(data['I_result'],1)
data = loadmat('./strategy_result/str_2.mat') 
str_2 = np.sum(data['I_result'],1)
data = loadmat('./strategy_result/str_1_2.mat') 
str_1_2 = np.sum(data['I_result'],1)

# %%
from matplotlib.ticker import FuncFormatter
def formatnum1(x, pos):
    if x == 0:
        return 0
    return '$%.1f$x$10^{8}$' % (x/1e8)
formatter1 = FuncFormatter(formatnum1)
def formatnum2(x, pos):
    if x == 0:
        return 0
    return '$%.1f$x$10^{4}$' % (x/1e4)
formatter2 = FuncFormatter(formatnum2)

font1 = {'family': 'Times New Roman',
         'weight': 'normal',
         'size': 25,
         }
## 矩形奥运会区域 
oly_x1= list(range(1,18))
oly_y2 = np.ones_like(oly_x1) * 130000
oly_y1 = np.ones_like(oly_x1) * 1e10
f, (ax1, ax2) = plt.subplots(2, 1, sharex=True, figsize=(16, 9))
plt.subplots_adjust(wspace =0, hspace =0)#调整子图间距

t = np.linspace(1,382,382)
ax1.plot(t, no_str_I,linewidth = '2', color='red', linestyle=':',label = 'no_str')
ax1.plot(t, str_1, linewidth = '2',color='blue', linestyle='--',label = 'str_1')
ax1.set_ylim([12000, 150000000])
ax1.spines['bottom'].set_position(('data',0))
ax1.set_xlim([0, 400])
ax1.set_ylabel('Cases of infectious', font1)
ax1.tick_params(labelsize = 20)
ax1.set_xlabel('$T$ (days after the opening ceremony)', font1)
ax1.yaxis.set_major_formatter(formatter1)
ax1.fill_between(oly_x,0, oly_y1, color='grey')
# ax1.set_yticks()

ax2.plot(t, str_2, linewidth = '2', color='peru', linestyle=':', label = 'str_2')
ax2.plot(t, str_1_2, linewidth = '2', color='olive', linestyle='-.', label = 'str_1_2')
ax2.set_ylim([0, 120000])
ax2.set_xlabel('$T$ (days after the opening ceremony)', font1)
ax2.set_ylabel('Cases of infectious', font1)
ax2.yaxis.set_major_formatter(formatter2)
ax2.fill_between(oly_x,0, oly_y2, color='grey')
# fig.legend()
# plt.xlabel('$T$ (days after the opening ceremony)', font1)
plt.xticks(fontproperties = 'Times New Roman', size = 20)
plt.yticks(fontproperties = 'Times New Roman', size = 20)
f.legend(prop={'family' : 'Times New Roman', 'size' : 20},bbox_to_anchor= (0.28, 0.85) )

f.show()
plt.savefig('test.jpg')
# Out:
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:50: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
f, (ax, ax2) = plt.subplots(2, 1, sharex=True, figsize=(16, 9))

# plot the same data on both axes
patientID_list = [2020035608, 
                  2020035233, 
                  2020035021, 
                  2020035350, 
                  2020035513, 
                  2020035478, 
                  2020034855,
                  2020034650,
                  2020034873,
                  2020035087,
                  2020035238,
                  2020035201,
                  2020036063]

date = list(range(15))
means = np.ones_like(date)
stds = np.ones_like(date)/8 
#_, date, means, stds, median, per_25, per_75 = get_interp_date_ratio_dict(patientID_list)
#means = move_avg(means, 7)
#stds = move_avg(stds, 7)
l1, = ax.plot(date, means, color='r', label='Mild patients: Absorb')
ax.fill_between(date, means-stds/1.5, means+stds, where=stds>0, interpolate=True, alpha=0.2)
ax2.plot(date, means, color='r', label='Mild patients: Absorb')
ax2.fill_between(date, means-stds/1.5, means+stds, where=stds>0, interpolate=True, alpha=0.2)


patientID_list = [2020035281, 
                  2020035151, 
                  2020035608, 
                  2020035199, 
                  2020035084, 
                  2020035231,
                  2020034976,
                  2020035016,
                  2020035153,
                  2020035362,
                  2020035775,
                  2020035147,
                  2020035395,
                  2020035210,
                  2020035137,
                  2020035396,
                  2020035085,
                  2020035365,
                  2020035142,
                  2020035224,
                 ]
date = list(range(15))
means = np.ones_like(date) *2 
stds = np.ones_like(date)/8 
#_, date, means, stds, median, per_25, per_75 = get_interp_date_ratio_dict(patientID_list)
#means = move_avg(means, 7)
#stds = move_avg(stds, 7)
l2, = ax.plot(date, means, color='b', label='Mild patients: Progress, Absorb')
ax.fill_between(date, means-stds/1.5, means+stds, where=stds>0, interpolate=True, alpha=0.2) 
ax.set_ylim([1.10, 2.5])
# Out:
# (1.1, 2.5)

# %%
oly_x= list(range(1,18))
oly_y = list(range(0,120000))
